# %%
import numpy as np
import pandas as pd

# %%
# Import Data
breweries = pd.read_csv('/Users/josephyuenpro/Documents/WPI/CS573/a4/breweries_us.csv')

# %%
# Drop duplicates
breweries = pd.DataFrame.drop_duplicates(breweries)

# Filter out unecessary headers - might add in later for an additional feature
breweries_filtered = breweries.filter(["brewery_name", "type", "state", "state_breweries"])

# Eliminate Puerto Rico as it is not a US state
breweries_filtered = breweries_filtered[breweries_filtered['state'] != 'puerto-rico']

# %%
# Replace names of headers that are double counts
# DECISION - made closed breweries count still as a part of their brewery type, so Brewpub-Closed is counted as a Brewpub
breweries_filtered.loc[breweries_filtered.type == 'Contract', 'type'] = 'ContractBrewery'
breweries_filtered.loc[breweries_filtered.type == 'Mircobrewery', 'type'] = 'Microbrewery'
breweries_filtered.loc[breweries_filtered.type == 'Brewpub-Closed', 'type'] = 'Brewpub'
breweries_filtered.loc[breweries_filtered.type == 'Microbrewery-Closed', 'type'] = 'Microbrewery'
breweries_filtered.loc[breweries_filtered.type == 'BOP-BrewOnPremise-Closed', 'type'] = 'BOP-BrewOnPremise'
breweries_filtered.loc[breweries_filtered.type == 'ContractBrewery-Closed', 'type'] = 'ContractBrewery'

# %%
brewery_types = breweries_filtered.type.unique()
brewery_types
# Out:
# array(['Brewpub', 'Microbrewery', 'RegionalBrewery', 'ContractBrewery',
#        'MultitapBar', 'BOP-BrewOnPremise'], dtype=object)

# %%
for brewery_type in brewery_types:
    temporary_df = breweries_filtered[breweries_filtered['type'] == brewery_type]
    temporary_df_group = temporary_df.groupby('state')
    temporary_df_group = pd.DataFrame(temporary_df_group.size().reset_index(name = 'state_' + brewery_type))
    breweries_filtered = pd.merge(breweries_filtered, temporary_df_group, how='left', on='state')
    breweries_filtered['state_' + brewery_type] = breweries_filtered['state_' + brewery_type].fillna(0)

# %%
breweries_filtered
# Out:
#                                            brewery_name             type  \
# 0                                    Valley Brewing Co.          Brewpub
# 1                                    Valley Brewing Co.          Brewpub
# 2                                     Valley Brewing Co     Microbrewery
# 3                                 Ukiah Brewing Company          Brewpub
# 4                                    Tustin Brewing Co.          Brewpub
# 5                                       Trumer Brauerei     Microbrewery
# 6                                       Trumer Brauerei  RegionalBrewery
# 7                               Triple Rock Brewing Co.          Brewpub
# 8                  Tied House Cafe & Brewery (San Jose)          Brewpub
# 9                  Tied House Cafe & Brewery (Mt. View)          Brewpub
# 10                             Thirsty Bear Brewing Co.     Microbrewery
# 11                               Third Street Ale Works          Brewpub
# 12                                        The Brewhouse          Brewpub
# 13                                     The Beach Chalet          Brewpub
# 14                            Telegraph Brewing Company     Microbrewery
# 15                        Taylor's Restaurant & Brewery          Brewpub
# 16                              Taps Fishouse & Brewery          Brewpub
# 17                                Tailgate Brewery, LLC  ContractBrewery
# 18                        Sudwerk Privatbrauerei Hübsch          Brewpub
# 19                              Sudwerk Brewery & Grill          Brewpub
# 20                                    Stumptown Brewery     Microbrewery
# 21                 Stone Brewing/World Bistro & Gardens  RegionalBrewery
# 22                    Steelhead Brewing Co - Burlingame          Brewpub
# 23                             Steelhead Brewery & Cafe          Brewpub
# 24                              Stadium Brewing Company          Brewpub
# 25                               St. Stan's Brewing Co.          Brewpub
# 26                            Speakeasy Ales and Lagers     Microbrewery
# 27                           Spanish Peaks Brewing Co.   ContractBrewery
# 28                             Sonoma Chicken & Brewery          Brewpub
# 29                    Solana Beach Brewery (Pizza Port)          Brewpub
# ...                                                 ...              ...
# 2374                   Fox River Brewing Co. (Appleton)          Brewpub
# 2375                                  Falls Brewing Co.     Microbrewery
# 2376                            Dos Banditos Restaurant          Brewpub
# 2377                                 Delafield Brewhaus          Brewpub
# 2378                          Cross Plains Brewery Inc.  ContractBrewery
# 2379                                     Courthouse Pub          Brewpub
# 2380                                         Corner Pub          Brewpub
# 2381                                   City Brewing Co.  RegionalBrewery
# 2382                                 Cherryland Brewing     Microbrewery
# 2383                            Capital Brewery Company     Microbrewery
# 2384                             Bull Falls Brewery LLC     Microbrewery
# 2385                      Brown Street Brewery / Bugsys     Microbrewery
# 2386              Brewmasters Pub, Restaurant & Brewery          Brewpub
# 2387                             Brewmaster's Pub, Ltd.          Brewpub
# 2388          Brewery Creek Inn, Restaurant and Brewery          Brewpub
# 2389                                Blue Heron Brew Pub          Brewpub
# 2390                                  Bellows Brew Crew          Brewpub
# 2391                           Appleton Brewing Company     Microbrewery
# 2392                                  Angry Minnow, The          Brewpub
# 2393                                         Ale Asylum          Brewpub
# 2394                                         Adler Brau     Microbrewery
# 2395                           Olde Heurich Brewing Co.  ContractBrewery
# 2396                            John Harvards Brewhouse          Brewpub
# 2397  Gordon Biersch Brewery Restaurant - Washington \n          Brewpub
# 2398                           Fischer Brewing Co. Inc.  ContractBrewery
# 2399                    Dumbarton Bridge Brewing Co LLC  ContractBrewery
# 2400                       District Chophouse & Brewery          Brewpub
# 2401                                Chophouse & Brewery          Brewpub
# 2402        Capitol City Brewing Company (Capitol Hill)          Brewpub
# 2403                       Capitol City Brewing Company          Brewpub
#
#               state  state_breweries  state_Brewpub  state_Microbrewery  \
# 0        california              284            184                77.0
# 1        california              284            184                77.0
# 2        california              284            184                77.0
# 3        california              284            184                77.0
# 4        california              284            184                77.0
# 5        california              284            184                77.0
# 6        california              284            184                77.0
# 7        california              284            184                77.0
# 8        california              284            184                77.0
# 9        california              284            184                77.0
